# %% [markdown]
# # Finally able to do some modelling

# %%
import statsmodels.api as sm
import pandas as pd
import numpy as np
import matplotlib 
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
import statsmodels.formula.api as smf
import patsy
from collections import Counter
from sklearn.cross_validation import train_test_split
import diagnostic_plots
from scipy.stats import boxcox
from sklearn.preprocessing import StandardScaler



import numpy as np
import pandas as pd
from sklearn.cross_validation import KFold
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error
from sklearn import preprocessing


import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV

from statsmodels.graphics.gofplots import ProbPlot
plt.style.use('seaborn') # pretty matplotlib plots
plt.rc('font', size=14)
plt.rc('figure', titlesize=18)
plt.rc('axes', labelsize=15)
plt.rc('axes', titlesize=18)

# %matplotlib inline
# Out:
# /Users/jennwon/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# /Users/jennwon/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# ## Loading all the data to make Diagnoistic Plot

# %%
outer_merged_df = pd.read_pickle('outer_merged_df.pkl')
outer_merged_df.rename(columns = {'Artist': 'artist', 'Song': 'song'}, inplace = True)
get_num_weeks_df = outer_merged_df[['artist', 'song', 'num_weeks']]

#print(get_num_weeks_df.sort_values('num_weeks', ascending = False))
#get_num_weeks_df.set_index(['artist', 'song'])
#get_num_weeks


#need to make sure spotify actually took all the songs that i was interested in and could find
completed_wo_num_weeks = pd.read_pickle('completed_spotify_files.pkl')
#print(completed_wo_num_weeks[completed_wo_num_weeks['song'] == 'Radioactive'])
completed_wo_num_weeks.drop_duplicates(['artist', 'song'], inplace = True)
# print(completed_wo_num_weeks)
joined = pd.merge(completed_wo_num_weeks, get_num_weeks_df, how = 'left')
#print(joined.sort_values('num_weeks', ascending = False))
joined.num_weeks.fillna(0, inplace = True)
joined.drop_duplicates(['artist', 'song'], inplace = True)
#len(joined)
#joined.num_weeks.sort_values(ascending=False)
#Counter(joined.song)
#joined
joined
# Out:
#        acousticness                                       analysis_url  \
# 0          0.399000  https://api.spotify.com/v1/audio-analysis/0LJB...
# 1          0.038200  https://api.spotify.com/v1/audio-analysis/717m...
# 2          0.005920  https://api.spotify.com/v1/audio-analysis/5UUE...
# 3          0.887000  https://api.spotify.com/v1/audio-analysis/6zsZ...
# 4          0.840000  https://api.spotify.com/v1/audio-analysis/0n5k...
# 5          0.151000  https://api.spotify.com/v1/audio-analysis/5XRm...
# 6          0.580000  https://api.spotify.com/v1/audio-analysis/3dOf...
# 7          0.694000  https://api.spotify.com/v1/audio-analysis/4u3h...
# 8          0.088500  https://api.spotify.com/v1/audio-analysis/5UDo...
# 9          0.291000  https://api.spotify.com/v1/audio-analysis/5SFe...
# 10         0.020000  https://api.spotify.com/v1/audio-analysis/73CH...
# 12         0.485000  https://api.spotify.com/v1/audio-analysis/3qXS...
# 13         0.948000  https://api.spotify.com/v1/audio-analysis/1zXE...
# 14         0.635000  https://api.spotify.com/v1/audio-analysis/36Ql...
# 15         0.443000  https://api.spotify.com/v1/audio-analysis/7tjt...
# 16         0.300000  https://api.spotify.com/v1/audio-analysis/4FmM...
# 17         0.930000  https://api.spotify.com/v1/audio-analysis/48A1...
# 18         0.285000  https://api.spotify.com/v1/audio-analysis/56Z4...
# 19         0.191000  https://api.spotify.com/v1/audio-analysis/0soc...
# 20         0.008150  https://api.spotify.com/v1/audio-analysis/7h57...
# 21         0.061100  https://api.spotify.com/v1/audio-analysis/6W7l...
# 22         0.130000  https://api.spotify.com/v1/audio-analysis/0IHa...
# 23         0.666000  https://api.spotify.com/v1/audio-analysis/5PIk...
# 24         0.000131  https://api.spotify.com/v1/audio-analysis/0tbr...
# 25         0.012000  https://api.spotify.com/v1/audio-analysis/7w7N...
# 26         0.946000  https://api.spotify.com/v1/audio-analysis/1aYK...
# 27         0.610000  https://api.spotify.com/v1/audio-analysis/0YYd...
# 28         0.986000  https://api.spotify.com/v1/audio-analysis/65sv...
# 29         0.001160  https://api.spotify.com/v1/audio-analysis/0cUK...
# 30         0.160000  https://api.spotify.com/v1/audio-analysis/6Vkz...
# ...             ...                                                ...
# 17947      0.970000  https://api.spotify.com/v1/audio-analysis/3ykF...
# 17948      0.124000  https://api.spotify.com/v1/audio-analysis/0amz...
# 17949      0.879000  https://api.spotify.com/v1/audio-analysis/0XPv...
# 17950      0.992000  https://api.spotify.com/v1/audio-analysis/2FTc...
# 17951      0.747000  https://api.spotify.com/v1/audio-analysis/6Dk3...
# 17952      0.062900  https://api.spotify.com/v1/audio-analysis/0OZX...
# 17953      0.735000  https://api.spotify.com/v1/audio-analysis/7maM...
# 17954      0.057100  https://api.spotify.com/v1/audio-analysis/5BPK...
# 17955      0.145000  https://api.spotify.com/v1/audio-analysis/4kIE...
# 17956      0.026000  https://api.spotify.com/v1/audio-analysis/0Whw...
# 17957      0.188000  https://api.spotify.com/v1/audio-analysis/24Id...
# 17958      0.054900  https://api.spotify.com/v1/audio-analysis/6LBf...
# 17959      0.018400  https://api.spotify.com/v1/audio-analysis/0uDb...
# 17960      0.252000  https://api.spotify.com/v1/audio-analysis/3BcG...
# 17961      0.053300  https://api.spotify.com/v1/audio-analysis/2f44...
# 17962      0.154000  https://api.spotify.com/v1/audio-analysis/3u8m...
# 17963      0.272000  https://api.spotify.com/v1/audio-analysis/43vH...
# 17964      0.068800  https://api.spotify.com/v1/audio-analysis/6IHd...
# 17965      0.169000  https://api.spotify.com/v1/audio-analysis/0PXH...
# 17966      0.129000  https://api.spotify.com/v1/audio-analysis/5L79...
# 17967      0.008670  https://api.spotify.com/v1/audio-analysis/3Q2t...
# 17968      0.016700  https://api.spotify.com/v1/audio-analysis/4Ajw...
# 17969      0.043900  https://api.spotify.com/v1/audio-analysis/4rmE...
# 17970      0.294000  https://api.spotify.com/v1/audio-analysis/26jv...
# 17971      0.277000  https://api.spotify.com/v1/audio-analysis/744w...
# 17972      0.410000  https://api.spotify.com/v1/audio-analysis/5uhU...
# 17973      0.293000  https://api.spotify.com/v1/audio-analysis/3PcN...
# 17974      0.056400  https://api.spotify.com/v1/audio-analysis/5JtP...
# 17975      0.033800  https://api.spotify.com/v1/audio-analysis/4mqA...
# 17976      0.029900  https://api.spotify.com/v1/audio-analysis/72Bz...
#
#                                                   artist  danceability  \
# 0                                             Themselves        0.4900
# 1                                               Vangelis        0.0643
# 2                                 Dexys Midnight Runners        0.5020
# 3                                          Charlie Haden        0.5130
# 4                                             Williamson        0.3120
# 5                                            Bad Company        0.5320
# 6                                           Janis Joplin        0.3900
# 16          285384  0.7470  [ccm, christian metal, christian music, deep c...
# 17          324893  0.3470                                          [soukous]
# 18          179627  0.5480                                         [jug band]
# 19          271687  0.7210                                                 []
# 20          235920  0.8330                              [chanson, french pop]
# 21          230720  0.9410  [bubble trance, bubblegum dance, eurodance, eu...
# 22          186200  0.4730  [hip pop, neo soul, pop, r&b, urban contemporary]
# 23          197267  0.4170  [dance pop, hip pop, pop, r&b, urban contempor...
# 24          217907  0.5660                                                 []
# 25          214852  0.9410                                                 []
# 26          195040  0.0561                                                 []
# 27          178160  0.6460                                                 []
# 28          189893  0.0459                                                 []
# 29          336294  0.9790                                                 []
# 30          357306  0.9280                   [gospel, world worship, worship]
# ...            ...     ...                                                ...
# 17947       273947  0.3300                                                 []
# 17948       190707  0.7390  [french folk pop, french reggae, french rock, ...
# 17949       343422  0.3980                                                 []
# 17950       177307  0.0154    [healing, meditation, native american, new age]
# 17951       149227  0.4310  [christmas, country gospel, cowboy western, na...
# 17952       238400  0.4840                                     [modern blues]
# 17953       203572  0.6500                                                 []
# 17954       240080  0.6630  [deep texas country, outlaw country, texas cou...
# 17955       110853  0.4690                                                 []
# 17956       189693  0.5370                                   [deep punk rock]
# 17957       305707  0.4220                           [mellow gold, soft rock]
# 17958       258147  0.7460                                                 []
# 17959       171160  0.8670  [jangle pop, power pop, pub rock, underground ...
# 17960       189373  0.6850  [contemporary country, country, country road, ...
# 17961       206147  0.7600  [contemporary country, country, country road, ...
# 17962       214827  0.7970  [contemporary country, country, country road, ...
# 17963       234307  0.5490                                                 []
# 17964       521373  0.7210                                                 []
# 17965       308773  0.8620                                                 []
# 17966       209693  0.6500                   [folk-pop, neo mellow, pop rock]
# 17967       234693  0.8330                   [folk-pop, neo mellow, pop rock]
# 17968       348707  0.6510                                                 []
# 17969       181600  0.6560                                                 []
# 17970       255724  0.8390                                                 []
# 17971       226828  0.4910                                 [folk, jazz blues]
# 17972       278800  0.2420                                 [folk, jazz blues]
# 17973       257560  0.8250                                 [folk, jazz blues]
# 17974       193107  0.8250  [alternative dance, indie pop, indie rock, ind...
# 17975       316027  0.7230                                                 []
# 17976       207746  0.5590  [dance pop, pop, post-teen pop, r&b, urban con...
#
#                            id  instrumentalness  key    ...     popularity  \
# 0      0LJBcbjQZJWtbe6KBhHZVT          0.257000    8    ...             19
# 1      717mHCBgkTNyE9G9qrt5AU          0.202000    4    ...             55
# 2      5UUEuHiuiRszWmE4vn1F95          0.871000    4    ...             61
# 3      6zsZUmX3J9KPd5FxtEX8zT          0.869000    7    ...             44
# 4      0n5kVyWQ9pmivACn9sB6BR          0.000840    4    ...              9
# 5      5XRmc3McELYoBc2rj0P39u          0.000001    0    ...             59
# 6      3dOfHE5J4Qsj1hJ35vnfn4          0.000184    5    ...             62
# 7      4u3hbJHvz3ROzMi7gLm7x0          0.000000    7    ...             52
# 8      5UDoSphfB1agTFhGReCfqQ          0.004360   11    ...             14
# 9      5SFew6BpZHtdeDBdxFdSRj          0.858000    1    ...             11
# 10     73CHSs62qc2JWiXi1ooWT3          0.847000    1    ...             34
# 12     3qXSBrqdauKrJ5mfncGtqq          0.504000    4    ...              1
# 13     1zXEtjL7jPP8ZEfmcfmmgO          0.909000    9    ...             43
# 14     36QlLljvzmCf0ABPtCwHhE          0.000000    1    ...             26
# 15     7tjtZHemW9GBp5VQhIiOHt          0.037400    4    ...             46
# 16     4FmMID3iwZmQqMfpZAEXCx          0.001180    9    ...             26
# 17     48A1CaEDQVk5TBU2bTZMnD          0.593000    5    ...             10
# 18     56Z4iUsKFbIx4XSnZseu28          0.000000    1    ...             13
# 19     0socivBHSFx0pOqjzqpkZc          0.000016   11    ...              0
# 20     7h57neC51fHepDp6LagycS          0.000000    0    ...             46
# 21     6W7l65kqEDbGauWLGmdmu3          0.005110    2    ...             41
# 22     0IHa9skAs65KA2AIH4RGFb          0.000005   10    ...             74
# 23     5PIkwFAZ5Vov3M6NFYNnAH          0.000000    7    ...             72
# 24     0tbrwZ3DDyinIhZQLrJVsd          0.000450    2    ...              0
# 25     7w7N9a1QtkHisGtCb3iUaM          0.000526    4    ...             45
# 26     1aYKKBfgHPfkzjH7pPXCAY          0.000000   10    ...             29
# 27     0YYd7RrbivjJ9v8MyCXUDd          0.000000    1    ...             15
# 28     65svmQ3SjiQBvTpziy8HaH          0.000000    3    ...              0
# 29     0cUKcWVeHAayLVN6wGLiAG          0.690000    7    ...              0
# 30     6Vkzf0DotL1ICs9noLC16Q          0.000000    6    ...             48
# ...                       ...               ...  ...    ...            ...
# 17947  3ykF7TyGPMUQvFpW5wnpM1          0.000719    4    ...              0
# 17948  0amzgkPlf0cqQOt466CQt0          0.000000    7    ...             28
# 17949  0XPvGzOQLB9hzF58Jil6O2          0.623000    3    ...             24
# 17950  2FTcfqt60GRpL2FoXqbXHL          0.901000    0    ...             45
# 17951  6Dk3EASTjfhDxY4ut3AitS          0.000000    9    ...             54
# 17952  0OZXSq05M7moJJY5V415fD          0.000145    0    ...             21
# 17953  7maMLnU7wTtCh9ze8uhqLK          0.000000    0    ...              0
# 17954  5BPKonvtgSRewMAMlolnHD          0.000000    2    ...             25
# 17955  4kIEyfupUtLlIi7bm3KrrY          0.000118    1    ...              0
# 17956  0Whwa5R0mtufr6Nb0dN6fm          0.153000    2    ...              7
# 17957  24IdPCimVnJJDRuB5YSDiS          0.003110   11    ...             72
# 17958  6LBfozDVA7crIeuaPAVVlE          0.000004    8    ...              0
# 17959  0uDbaQ0mUscJhYV2dn7bNm          0.000000   11    ...             20
# 17960  3BcGTyGnofcaQlxEaHyuPD          0.000000    2    ...             52
# 17961  2f44w3kcYPm9NEVXmbCoTI          0.000000    7    ...             52
# 17962  3u8m4E4pJn43otDkw2wXBs          0.000000    9    ...             52
# 17963  43vHo2Iis2QX3sle9o4S3g          0.000000    0    ...              0
# 17964  6IHd0OhQbXVv9VcQjKS7L0          0.008790    9    ...             20
# 17965  0PXHA9nXcu4UOJFXvye9LE          0.025500    1    ...             52
# 17966  5L79aNYCTKiZq7vaOElXYj          0.000000    6    ...             59
# 17967  3Q2tKt6gKdn9LUMcHFxNJy          0.000000    7    ...             59
# 17968  4Ajw0QFjYVh8zrlItY2i5M          0.000010    9    ...              1
# 17969  4rmEJilD24SBIXm9Bpz4dB          0.000355    0    ...              6
# 17970  26jvFY5r6AN5kuJmih4GpF          0.000001    8    ...             27
# 17971  744wbwIqeCp75NRruMuMKT          0.000012   11    ...             35
# 17972  5uhULfoDgTvz7BeWlqrV4a          0.000000    7    ...             35
# 17973  3PcNsWAoCaoK63NIBdKj8n          0.000006    9    ...             35
# 17974  5JtPGzRgrWxkXX9LoROq3d          0.000058    0    ...             65
# 17975  4mqAag0mULGpUKHqd9WdEV          0.000015    4    ...             24
# 17976  72Bz4ciRZPBcVSw0nrZDHi          0.000000    8    ...             65
#
#                                                     song  speechiness  \
# 0                                          The No Music.       0.1670
# 1                                Antarctica (Remastered)       0.0363
# 2                            The Projected Passion Revue       0.0303
# 3                                Beyond The Missouri Sky       0.0526
# 4                             The Trashcan Electric e.p.       0.0477
# 5                         Run With The Pack (Remastered)       0.0337
# 6                                 Pearl (Legacy Edition)       0.0298
# 7      Come A Little Bit Closer: The Best Of Jay & Th...       0.0400
# 8                                   Diarrhea of a Madman       0.0537
# 9                                     The Singles Part 1       0.0764
# 10                                          Warung Beach       0.0496
# 12                                   Simply Newage Moods       0.0337
# 13                                      The Edge Of Love       0.0443
# 14                                      Praise & Worship       0.0366
# 15                    Still Rovin' After All These Years       0.1250
# 16                                            Powerhouse       0.0400
# 17                             Les grands succès, Vol. 5       0.0523
# 18                                  Vanguard Visionaries       0.1320
# 19                                      Knowledge Zombie       0.0485
# 20                             MillésimeS (Live 2013-14)       0.0576
# 21                                        Gonna Move Ya!       0.0944
# 22                              The Diary Of Alicia Keys       0.1200
# 23                                         Charmbracelet       0.0664
# 24                                               Trilogy       0.0412
# 25                           Los Auténticos Reggaementes       0.1580
# 26                           Worshipsongs: Draw Me Close       0.0346
# 27                                   Bézu au bal Musette       0.0555
# 28     Ceol Tacsi (Exclusive Live Performances From O...       0.0417
# 29                        The Best Hardstyle & Jump Ever       0.0639
# 30                                                Decade       0.0690
# ...                                                  ...          ...
# 17947  Songs & Memories Vol 2, 4 CD Pack - Persian Music       0.0345
# 17948                                   Safari Croisière       0.3440
# 17949          Sessiz Bir Kelebeğin Rüyaları ve Dansları       0.0478
# 17950                                           Voyagers       0.0444
# 17951                                Best Of Patsy Cline       0.0282
# 17952                                        Believe It!       0.0298
# 17953                                  The Ethiopian Son       0.2990
# 17954                                Latest and Greatest       0.0257
# 17955                                          Split EP!       0.2260
# 17956                                     GBH Demos 1977       0.0900
# 17957           Hello, I Must Be Going! (Deluxe Edition)       0.0378
# 17958                         Tarzan Original Soundtrack       0.0293
# 17959                             Archive Series, Vol. 1       0.0278
# 17960             Playlist: The Very Best Of Phil Vassar       0.0277
# 17961                             Greatest Hits Volume 1       0.0284
# 17962                                 Shaken Not Stirred       0.0305
# 17963                             Totally Country Vol. 6       0.0246
# 17964                          Let's Clean Up the Ghetto       0.0302
# 17965                    Chinese Wall (Expanded Edition)       0.0340
# 17966       The World From The Side Of The Moon (Deluxe)       0.0383
# 17967                          Behind The Light (Deluxe)       0.0730
# 17968                                      Motown Review       0.0305
# 17969                                   Philly Devotions       0.0536
# 17970               Get Down Or Lay Down (U.S. Explicit)       0.2600
# 17971                                          Rock Away       0.0264
# 17972                                        Phoebe Snow       0.0318
# 17973                       The Very Best Of Phoebe Snow       0.1300
# 17974                           Wolfgang Amadeus Phoenix       0.0429
# 17975            All of Phyllis Nelson (14 Songs & Hits)       0.0382
# 17976                                        Do It Again       0.0515
#
#          tempo time_signature  \
# 0      120.323              4
# 1       70.319              4
# 2      118.886              4
# 3      102.472              4
# 4       77.433              3
# 5      143.029              4
# 6      147.016              3
# 7      131.133              4
# 8       93.619              4
# 9      123.997              4
# 10     125.017              5
# 12     164.165              4
# 13     146.778              4
# 14     122.841              4
# 15     192.450              4
# 16      96.861              4
# 17     136.048              4
# 18      96.423              4
# 19     104.856              4
# 20      85.374              4
# 21     140.014              4
# 22      82.967              4
# 23     119.915              4
# 24     170.020              4
# 25     165.834              4
# 26     106.662              5
# 27     185.155              3
# 28     105.750              4
# 29     140.005              4
# 30      96.959              4
# ...        ...            ...
# 17947   85.003              3
# 17948   89.426              4
# 17949   77.435              4
# 17950   66.160              4
# 17951   92.972              4
# 17952  106.961              1
# 17953  112.673              5
# 17954  117.995              4
# 17955  119.493              4
# 17956  201.895              4
# 17957  140.494              4
# 17958   96.626              4
# 17959  129.549              4
# 17960  168.121              3
# 17961   91.845              4
# 17962   90.907              4
# 17963  139.945              3
# 17964  122.043              4
# 17965  169.956              4
# 17966  117.992              4
# 17967  125.909              4
# 17968  132.992              4
# 17969  114.712              4
# 17970   91.136              4
# 17971   91.989              4
# 17972  131.820              4
# 17973   96.351              4
# 17974  144.085              4
# 17975  121.475              4
# 17976   95.979              4
#
#                                               track_href            type  \
# 0      https://api.spotify.com/v1/tracks/0LJBcbjQZJWt...  audio_features
# 1      https://api.spotify.com/v1/tracks/717mHCBgkTNy...  audio_features
# 2      https://api.spotify.com/v1/tracks/5UUEuHiuiRsz...  audio_features
# 3      https://api.spotify.com/v1/tracks/6zsZUmX3J9KP...  audio_features
# 4      https://api.spotify.com/v1/tracks/0n5kVyWQ9pmi...  audio_features
# 5      https://api.spotify.com/v1/tracks/5XRmc3McELYo...  audio_features
# 6      https://api.spotify.com/v1/tracks/3dOfHE5J4Qsj...  audio_features
# 7      https://api.spotify.com/v1/tracks/4u3hbJHvz3RO...  audio_features
# 8      https://api.spotify.com/v1/tracks/5UDoSphfB1ag...  audio_features
# 9      https://api.spotify.com/v1/tracks/5SFew6BpZHtd...  audio_features
# 10     https://api.spotify.com/v1/tracks/73CHSs62qc2J...  audio_features
# 12     https://api.spotify.com/v1/tracks/3qXSBrqdauKr...  audio_features
# 13     https://api.spotify.com/v1/tracks/1zXEtjL7jPP8...  audio_features
# 14     https://api.spotify.com/v1/tracks/36QlLljvzmCf...  audio_features
# 15     https://api.spotify.com/v1/tracks/7tjtZHemW9GB...  audio_features
# 16     https://api.spotify.com/v1/tracks/4FmMID3iwZmQ...  audio_features
# 17     https://api.spotify.com/v1/tracks/48A1CaEDQVk5...  audio_features
# 18     https://api.spotify.com/v1/tracks/56Z4iUsKFbIx...  audio_features
# 19     https://api.spotify.com/v1/tracks/0socivBHSFx0...  audio_features
# 20     https://api.spotify.com/v1/tracks/7h57neC51fHe...  audio_features
# 21     https://api.spotify.com/v1/tracks/6W7l65kqEDbG...  audio_features
# 22     https://api.spotify.com/v1/tracks/0IHa9skAs65K...  audio_features
# 23     https://api.spotify.com/v1/tracks/5PIkwFAZ5Vov...  audio_features
# 24     https://api.spotify.com/v1/tracks/0tbrwZ3DDyin...  audio_features
# 25     https://api.spotify.com/v1/tracks/7w7N9a1QtkHi...  audio_features
# 26     https://api.spotify.com/v1/tracks/1aYKKBfgHPfk...  audio_features
# 27     https://api.spotify.com/v1/tracks/0YYd7RrbivjJ...  audio_features
# 28     https://api.spotify.com/v1/tracks/65svmQ3SjiQB...  audio_features
# 29     https://api.spotify.com/v1/tracks/0cUKcWVeHAay...  audio_features
# 30     https://api.spotify.com/v1/tracks/6Vkzf0DotL1I...  audio_features
# ...                                                  ...             ...
# 17947  https://api.spotify.com/v1/tracks/3ykF7TyGPMUQ...  audio_features
# 17948  https://api.spotify.com/v1/tracks/0amzgkPlf0cq...  audio_features
# 17949  https://api.spotify.com/v1/tracks/0XPvGzOQLB9h...  audio_features
# 17950  https://api.spotify.com/v1/tracks/2FTcfqt60GRp...  audio_features
# 17951  https://api.spotify.com/v1/tracks/6Dk3EASTjfhD...  audio_features
# 17952  https://api.spotify.com/v1/tracks/0OZXSq05M7mo...  audio_features
# 17953  https://api.spotify.com/v1/tracks/7maMLnU7wTtC...  audio_features
# 17954  https://api.spotify.com/v1/tracks/5BPKonvtgSRe...  audio_features
# 17955  https://api.spotify.com/v1/tracks/4kIEyfupUtLl...  audio_features
# 17956  https://api.spotify.com/v1/tracks/0Whwa5R0mtuf...  audio_features
# 17957  https://api.spotify.com/v1/tracks/24IdPCimVnJJ...  audio_features
# 17958  https://api.spotify.com/v1/tracks/6LBfozDVA7cr...  audio_features
# 17959  https://api.spotify.com/v1/tracks/0uDbaQ0mUscJ...  audio_features
# 17960  https://api.spotify.com/v1/tracks/3BcGTyGnofca...  audio_features
# 17961  https://api.spotify.com/v1/tracks/2f44w3kcYPm9...  audio_features
# 17962  https://api.spotify.com/v1/tracks/3u8m4E4pJn43...  audio_features
# 17963  https://api.spotify.com/v1/tracks/43vHo2Iis2QX...  audio_features
# 17964  https://api.spotify.com/v1/tracks/6IHd0OhQbXVv...  audio_features
# 17965  https://api.spotify.com/v1/tracks/0PXHA9nXcu4U...  audio_features
# 17966  https://api.spotify.com/v1/tracks/5L79aNYCTKiZ...  audio_features
# 17967  https://api.spotify.com/v1/tracks/3Q2tKt6gKdn9...  audio_features
# 29     spotify:track:0cUKcWVeHAayLVN6wGLiAG  0.7280       0.0
# 30     spotify:track:6Vkzf0DotL1ICs9noLC16Q  0.5040       0.0
# ...                                     ...     ...       ...
# 17947  spotify:track:3ykF7TyGPMUQvFpW5wnpM1  0.4990       0.0
# 17948  spotify:track:0amzgkPlf0cqQOt466CQt0  0.7020       0.0
# 17949  spotify:track:0XPvGzOQLB9hzF58Jil6O2  0.1410       0.0
# 17950  spotify:track:2FTcfqt60GRpL2FoXqbXHL  0.3820       0.0
# 17951  spotify:track:6Dk3EASTjfhDxY4ut3AitS  0.8710       0.0
# 17952  spotify:track:0OZXSq05M7moJJY5V415fD  0.7280       0.0
# 17953  spotify:track:7maMLnU7wTtCh9ze8uhqLK  0.5690       0.0
# 17954  spotify:track:5BPKonvtgSRewMAMlolnHD  0.3710       0.0
# 17955  spotify:track:4kIEyfupUtLlIi7bm3KrrY  0.6540       0.0
# 17956  spotify:track:0Whwa5R0mtufr6Nb0dN6fm  0.9350       0.0
# 17957  spotify:track:24IdPCimVnJJDRuB5YSDiS  0.4420       0.0
# 17958  spotify:track:6LBfozDVA7crIeuaPAVVlE  0.6260       0.0
# 17959  spotify:track:0uDbaQ0mUscJhYV2dn7bNm  0.9560       0.0
# 17960  spotify:track:3BcGTyGnofcaQlxEaHyuPD  0.4430       0.0
# 17961  spotify:track:2f44w3kcYPm9NEVXmbCoTI  0.5900       0.0
# 17962  spotify:track:3u8m4E4pJn43otDkw2wXBs  0.7440       0.0
# 17963  spotify:track:43vHo2Iis2QX3sle9o4S3g  0.2680       0.0
# 17964  spotify:track:6IHd0OhQbXVv9VcQjKS7L0  0.9460       0.0
# 17965  spotify:track:0PXHA9nXcu4UOJFXvye9LE  0.4970       0.0
# 17966  spotify:track:5L79aNYCTKiZq7vaOElXYj  0.4810       0.0
# 17967  spotify:track:3Q2tKt6gKdn9LUMcHFxNJy  0.4490       0.0
# 17968  spotify:track:4Ajw0QFjYVh8zrlItY2i5M  0.8230       5.0
# 17969  spotify:track:4rmEJilD24SBIXm9Bpz4dB  0.5560       0.0
# 17970  spotify:track:26jvFY5r6AN5kuJmih4GpF  0.7860       0.0
# 17971  spotify:track:744wbwIqeCp75NRruMuMKT  0.5770       0.0
# 17972  spotify:track:5uhULfoDgTvz7BeWlqrV4a  0.5960       0.0
# 17973  spotify:track:3PcNsWAoCaoK63NIBdKj8n  0.8350       0.0
# 17974  spotify:track:5JtPGzRgrWxkXX9LoROq3d  0.7070       0.0
# 17975  spotify:track:4mqAag0mULGpUKHqd9WdEV  0.7730       0.0
# 17976  spotify:track:72Bz4ciRZPBcVSw0nrZDHi  0.4110      11.0
#
# [17970 rows x 23 columns]

# %% [markdown]
# # All the way to the top (EDA)
# I want to do exploratory data analysis of just the songs that were able to crack the top 100 at least once

# %%
joined['duration'] = joined.duration_ms / 1000
joined.duration_ms = joined.duration
joined.drop('duration', 1, inplace = True)
#joined.rename(columns = {'duration'})
joined[joined.num_weeks > 0].describe()
#Counter(joined.tempo)
#joined.duration


#acoustiness is not normally distrbuted there is a lot more at the bottom that the top
#energy is skewed with left tail
#valence has outliers to the right
#speechiness is skewed with right tail
#instrumentalness isnt that helpful
#liveness is skewed with right tail
#need to do counts for keys and mode
#popularity is shifted to the right
#mean of tempo is 120bpm
# Out:
#        acousticness  danceability  duration_ms       energy  instrumentalness  \
# count   1526.000000   1526.000000  1526.000000  1526.000000       1526.000000
# mean       0.274836      0.607328   227.949311     0.621428          0.032665
# std        0.273880      0.155742    75.624830     0.199430          0.136114
# min        0.000014      0.148000    71.967000     0.047700          0.000000
# 25%        0.037675      0.505000   186.306500     0.473000          0.000000
# 50%        0.177000      0.615000   217.920000     0.639000          0.000004
# 75%        0.474750      0.721000   256.309750     0.779000          0.000520
# max        0.974000      0.959000  1561.133000     0.997000          0.966000
#
#                key     liveness     loudness         mode   popularity  \
# count  1526.000000  1526.000000  1526.000000  1526.000000  1526.000000
# mean      5.198558     0.178119    -8.562716     0.741153    53.530144
# std       3.561068     0.142426     3.889808     0.438145    20.914786
# min       0.000000     0.023800   -27.119000     0.000000     0.000000
# 25%       2.000000     0.087700   -11.123250     0.000000    40.000000
# 50%       5.000000     0.122000    -7.824000     1.000000    57.000000
# 75%       8.000000     0.225750    -5.553250     1.000000    69.000000
# max      11.000000     0.989000     2.291000     1.000000   100.000000
#
#        speechiness        tempo  time_signature      valence    num_weeks
# count  1526.000000  1526.000000     1526.000000  1526.000000  1526.000000
# mean      0.074682   120.427870        3.937746     0.587075    12.899738
# std       0.083527    27.721597        0.312668     0.239294     8.541880
# min       0.022800    60.709000        1.000000     0.037800     1.000000
# 25%       0.032400    99.938750        4.000000     0.391000     6.000000
# 50%       0.041950   119.903500        4.000000     0.610500    12.000000
# 75%       0.071950   137.400500        4.000000     0.791750    19.000000
# max       0.733000   207.673000        5.000000     0.990000    60.000000

# %%
#joined[joined.num_weeks == 0].describe()

# %%
top_songs = joined[joined.num_weeks > 0].drop(['analysis_url', 'artist', 'uri', 'type', 'track_href'], 1).sort_values('num_weeks', ascending = False)
top_songs.head(20)
# Out:
#        acousticness  danceability  duration_ms  energy  \
# 7185         0.5080         0.588      224.867   0.684
# 6024         0.2690         0.640      262.533   0.743
# 17403        0.0344         0.684      211.800   0.794
# 9628         0.2170         0.675      216.667   0.885
# 15907        0.4140         0.748      244.960   0.524
# 15908        0.1570         0.532      208.373   0.869
# 3499         0.0524         0.416      294.533   0.446
# 592          0.0476         0.811      188.754   0.879
# 6789         0.2540         0.583      219.493   0.584
# 7922         0.0908         0.813      236.933   0.882
# 2533         0.6940         0.585      240.166   0.303
# 15338        0.1070         0.848      248.373   0.953
# 4742         0.0322         0.734      216.360   0.635
# 13590        0.4630         0.731      165.387   0.469
# 14616        0.0435         0.743      224.773   0.807
# 2485         0.0340         0.818      225.983   0.803
# 8749         0.0141         0.441      270.800   0.563
# 1571         0.2180         0.755      246.467   0.765
# 13227        0.1160         0.642      212.693   0.754
# 2833         0.1140         0.680      330.200   0.394
#
#                                                    genre  \
# 7185   [contemporary country, country, country dawn, ...
# 6024             [neo mellow, piano rock, pop, pop rock]
# 17403  [dance pop, edm, electropop, metropopolis, pop...
# 9628   [dance pop, neo mellow, pop, pop quebecois, po...
# 15907             [edm, electropop, pop, tropical house]
# 15908             [edm, electropop, pop, tropical house]
# 3499   [contemporary country, country, country dawn, ...
# 592             [dance pop, hip pop, pop, post-teen pop]
# 6789   [dance pop, neo mellow, pop, pop rock, post-te...
# 7922   [bubblegum dance, eurodance, europop, german t...
# 2533   [acoustic pop, neo mellow, pop, pop rock, vira...
# 15338                            [hip house, miami bass]
# 4742   [australian pop, dance pop, europop, neo mello...
# 13590                             [contemporary country]
# 14616                                              [pop]
# 2485                     [dance pop, pop, post-teen pop]
# 8749                 [neo mellow, pop rock, post-grunge]
# 1571   [dance pop, europop, hip pop, pop, pop rap, po...
# 13227                                      [vocal house]
# 2833                                    [new jack swing]
#
#                            id  instrumentalness  key  liveness  loudness  \
# 7185   4xInIiKipU1mtUogJ3ZdYr          0.000000    1    0.1410    -5.154
# 6024   5fVZC9GiM4e8vu99W0Xf6J          0.000000   10    0.1010    -4.080
# 17403  7gUpO6td4OOnu0Lf9vhcIV          0.044500    8    0.1110    -6.080
# 9628   0KpfYajJVVGgQ32Dby7e9i          0.000000    1    0.0860    -4.432
# 15907  7BKLCZ1jbUBVqRi2FVlTVw          0.000000    8    0.1110    -5.599
# 15908  1i1fxkWeaMmKEB4T7zqbzK          0.005080   11    0.1360    -5.094
# 3499   65B1tEOv5W294uCKbmEcFV          0.000000    7    0.0891    -9.557
# 592    0ifSeVGUr7py5GggttDhXw          0.000002    9    0.1090    -3.724
# 6789   3f3omU8n47Mqyab5nCaGyT          0.000000    5    0.1230    -5.362
# 7922   3pEuO9J2MTEmec8kUfYYvl          0.004570    7    0.1470    -7.575
# 2533   05pKAafT85jeeNhZ6kq7HT          0.000000    4    0.1150   -10.058
# 15338  7AYr5rYQFXJzLSJK9vx6om          0.000000    9    0.3420    -5.040
# 4742   6QLU1GKy2Zh2mOh2uoJ0TV          0.000000    5    0.0808    -7.030
# 13590  7mldq42yDuxiUNn08nvzHO          0.000001    5    0.1030    -7.226
# 14616  3tCwjWLicbjsMCvXhN0WOE          0.000000    1    0.3090    -3.780
# 2485   6b8Be6ljOzmkOmFslEb23P          0.000000    1    0.1530    -4.282
# 8749   2EVNYzHWebyLvKxPX6Ozt8          0.000004    6    0.1010    -7.274
# 1571   66ZcOcouenzZEnzTJvoFmH          0.000000    1    0.1620    -3.475
# 13227  6atodngcu0uc9uHkP1mdKS          0.037500    1    0.0601    -7.649
# 2833   6hxK603i8PoKCsGwnvLOeD          0.001450    6    0.0938   -11.833
#
#        mode  popularity                          song  speechiness    tempo  \
# 7185      1          66                  Need You Now       0.0288   85.997
# 6024      1          69            How To Save A Life       0.0379  122.035
# 17403     0          75                        Lights       0.0375  120.024
# 9628      0          71              Hey, Soul Sister       0.0436   97.030
# 15907     1          83                        Closer       0.0338   95.010
# 15908     1          83             Don't Let Me Down       0.1720  159.803
# 3499      0          51              I Hope You Dance       0.0291  151.328
# 592       1          75           All About That Bass       0.0514  134.064
# 6789      0          72                     Breakaway       0.0314  140.039
# 7922      1          47                 Another Night       0.0402  125.983
# 2533      1          75               I Won't Give Up       0.0398  136.703
# 15338     1          41  C'mon N' Ride It (The Train)       0.0679  136.050
# 4742      1          64                     Unwritten       0.0816   96.990
# 13590     1          72         Body Like A Back Road       0.0326   98.963
# 14616     1          68                          Rude       0.0364  144.062
# 2485      1          84                     24K Magic       0.0797  106.970
# 8749      1          52           Everything You Want       0.0251   85.711
# 1571      1          69              The Sweet Escape       0.0356  119.954
# 13227     1          37            This Is Your Night       0.0272  127.025
# 2833      0          58            Return Of The Mack       0.0391  141.504
#
#        time_signature  valence  num_weeks
# 7185                4    0.121       60.0
# 6024                4    0.361       58.0
# 17403               4    0.773       57.0
# 9628                4    0.768       54.0
# 15907               4    0.661       52.0
# 15908               4    0.422       52.0
# 3499                4    0.278       48.0
# 592                 4    0.962       47.0
# 6789                4    0.136       46.0
# 7922                4    0.874       45.0
# 2533                3    0.142       44.0
# 15338               4    0.951       42.0
# 4742                4    0.931       42.0
# 13590               4    0.631       41.0
# 14616               4    0.899       41.0
# 2485                4    0.632       41.0
# 8749                4    0.209       41.0
# 1571                4    0.737       40.0
# 13227               4    0.736       40.0
# 2833                4    0.375       40.0

# %%
#mask = joined.num_weeks < 0
not_top_songs = joined[joined.num_weeks == 0].drop(['analysis_url', 'artist', 'uri', 'type', 'track_href'], 1).sort_values('num_weeks', ascending = False)
#grab_random_index = np.random.randint(0, len(not_top_songs), len(top_songs))
#not_top_songs.reset_index(inplace = True)
not_top_songs
sampled_not_top = not_top_songs.sample(len(top_songs))
sampled_not_top
# Out:
#        acousticness  danceability  duration_ms  energy  \
# 10533      0.742000         0.384      129.828   0.430
# 7070       0.239000         0.936      124.056   0.523
# 5573       0.599000         0.510      112.666   0.645
# 4362       0.242000         0.581      369.231   0.735
# 4164       0.682000         0.437      149.493   0.916
# 13909      0.000114         0.520      218.906   0.972
# 8188       0.845000         0.393      118.960   0.358
# 2598       0.398000         0.508      169.427   0.522
# 7585       0.000003         0.638      272.560   0.777
# 3217       0.702000         0.526      171.533   0.675
# 12596      0.477000         0.458      270.933   0.861
# 9417       0.098100         0.686      267.627   0.603
# 14065      0.706000         0.670      880.933   0.341
# 2859       0.093900         0.668      235.625   0.640
# 17096      0.262000         0.672      178.200   0.570
# 15846      0.961000         0.319      224.333   0.102
# 14793      0.249000         0.521      195.293   0.743
# 6917       0.002070         0.632      212.907   0.721
# 14886      0.390000         0.530      286.173   0.379
# 5241       0.008680         0.565      212.647   0.849
# 8204       0.955000         0.758      114.640   0.393
# 13174      0.947000         0.528      174.222   0.421
# 10248      0.239000         0.793      273.693   0.647
# 6327       0.220000         0.795      173.827   0.829
# 10373      0.001320         0.883      147.948   0.409
# 5687       0.009030         0.468      294.467   0.800
# 2129       0.847000         0.370      165.707   0.383
# 14874      0.369000         0.572      127.093   0.519
# 14878      0.400000         0.415      170.240   0.538
# 14167      0.397000         0.739      202.547   0.585
# ...             ...           ...          ...     ...
# 2126       0.084300         0.655      386.360   0.685
# 9903       0.000345         0.294      175.333   0.986
# 15900      0.054000         0.633      250.813   0.795
# 8895       0.082900         0.687      247.267   0.619
# 671        0.455000         0.422      229.867   0.408
# 17762      0.003670         0.789      231.320   0.765
# 14023      0.299000         0.597      225.400   0.517
# 5419       0.160000         0.840      188.493   0.571
# 3780       0.022500         0.635      206.067   0.606
# 1110       0.013200         0.849      242.600   0.645
# 388        0.177000         0.712      214.280   0.936
# 16873      0.432000         0.563      202.333   0.524
# 13818      0.286000         0.472      237.347   0.673
# 12322      0.106000         0.830      197.627   0.948
# 8011       0.516000         0.806      222.440   0.870
# 746        0.538000         0.703      328.240   0.917
# 16843      0.000014         0.468      218.133   0.996
# 7475       0.005070         0.555      203.387   0.988
# 10664      0.049600         0.384      248.187   0.744
# 4593       0.634000         0.377      139.413   0.760
# 17778      0.121000         0.741      187.147   0.533
# 1477       0.667000         0.512      275.000   0.297
# 15127      0.001030         0.524      221.387   0.745
# 8868       0.014100         0.755      212.667   0.493
# 5587       0.114000         0.459      198.827   0.400
# 9748       0.003490         0.318      212.880   0.973
# 11487      0.496000         0.324      155.240   0.387
# 14556      0.000017         0.371      238.573   0.731
# 12120      0.021800         0.790      314.333   0.490
# 4826       0.037300         0.714      283.560   0.788
#
#                                                    genre  \
# 10533                                                 []
# 7070                                                  []
# 5573   [country, country gospel, country rock, cowboy...
# 4362                                                  []
# 4164                                                [oi]
# 13909                                                 []
# 8188                                                  []
# 2598                                                  []
# 7585   [alternative dance, dance-punk, electroclash, ...
# 3217   [brill building pop, classic girl group, class...
# 12596                                   [deep soft rock]
# 9417   [crunk, dirty south rap, gangster rap, pop rap...
# 14065  [acoustic blues, blues, country blues, delta b...
# 2859                                                  []
# 17096  [adult standards, brill building pop, bubblegu...
# 15846                                                 []
# 14793                                        [soft rock]
# 6917            [disco, funk, motown, quiet storm, soul]
# 14886                                  [flamenco, rumba]
# 5241                               [permanent wave, pop]
# 8204                         [rock-and-roll, rockabilly]
# 13174  [adult standards, brill building pop, christma...
# 10248  [dance pop, deep pop r&b, hip pop, neo soul, n...
# 6327   [art pop, art rock, dance rock, glam rock, new...
# 10373                             [reggae, roots reggae]
# 5687   [alternative rock, classic rock, dance rock, g...
# 2129   [doo-wop, jazz blues, rhythm and blues, rock-a...
# 14874                                                 []
# 14878                                                 []
# 14167  [classic soul, funk, memphis soul, motown, qui...
# ...                                                  ...
# 2126                         [jazz trumpet, smooth jazz]
# 9903                 [beatdown, hardcore, straight edge]
# 15900                            [jangle pop, power pop]
# 8895   [dance pop, hip pop, pop, pop rap, post-teen p...
# 671    [adult standards, bubblegum pop, mellow gold, ...
# 17762  [dance rock, freestyle, new romantic, new wave...
# 14023  [blues, blues-rock, british blues, classic roc...
# 5419   [dance pop, dirty south rap, gangster rap, hip...
# 1087      1.0
# 1936      1.0
# 1131      1.0
# 6488      1.0
# 11691     1.0
# 5399      1.0
# 7932      1.0
# 9246      1.0
# 6575      1.0
# 454       1.0
# 15058     1.0
# 336       1.0
# 5763      1.0
#          ...
# 9727     35.0
# 3232     35.0
# 2574     36.0
# 8900     36.0
# 4701     37.0
# 2134     38.0
# 14190    38.0
# 15914    39.0
# 14230    39.0
# 1571     40.0
# 2833     40.0
# 11159    40.0
# 13227    40.0
# 8749     41.0
# 2485     41.0
# 14616    41.0
# 13590    41.0
# 4742     42.0
# 15338    42.0
# 2533     44.0
# 7922     45.0
# 6789     46.0
# 592      47.0
# 3499     48.0
# 15908    52.0
# 15907    52.0
# 9628     54.0
# 17403    57.0
# 6024     58.0
# 7185     60.0
# Name: num_weeks, Length: 1526, dtype: float64

# %%
#joined.drop(['analysis_url', 'artist', 'id', 'song', 'track_href', 'type', 'uri'], inplace = True, axis =1)
joined.columns
sns.pairplot(joined)
#i also want to look at the distribution of num of weeks in the charts without the 0
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
Counter(joined.num_weeks)
# Out:
# Counter({1.0: 112,
#          2.0: 61,
#          3.0: 64,
#          4.0: 47,
#          5.0: 52,
#          6.0: 64,
#          7.0: 42,
#          8.0: 48,
#          9.0: 75,
#          10.0: 68,
#          11.0: 72,
#          12.0: 72,
#          13.0: 61,
#          14.0: 82,
#          15.0: 61,
#          16.0: 55,
#          17.0: 52,
#          18.0: 45,
#          19.0: 44,
#          20.0: 158,
#          21.0: 31,
#          22.0: 30,
#          23.0: 14,
#          24.0: 9,
#          25.0: 17,
#          26.0: 11,
#          27.0: 9,
#          28.0: 8,
#          29.0: 10,
#          30.0: 8,
#          31.0: 5,
#          32.0: 3,
#          33.0: 4,
#          34.0: 2,
#          35.0: 2,
#          36.0: 2,
#          37.0: 1,
#          38.0: 2,
#          39.0: 2,
#          40.0: 4,
#          41.0: 4,
#          42.0: 2,
#          44.0: 1,
#          45.0: 1,
#          46.0: 1,
#          47.0: 1,
#          48.0: 1,
#          52.0: 2,
#          54.0: 1,
#          57.0: 1,
#          58.0: 1,
#          60.0: 1})

# %%
#y_transformed, _ = boxcox(joined.num_weeks)

# %%
#using boxcox to transform y-var
y_transformed, _ = boxcox(joined.num_weeks)

# %%
pd.Series(y_transformed).hist()

# %%
#joined.drop([''])

# %% [markdown]
# ## Trying to find my base linear regression model

# %%
equation = 'num_weeks ~ acousticness  + danceability + duration_ms + energy + instrumentalness + key + liveness + loudness + mode + popularity + speechiness + tempo + time_signature + valence'
#y, X = patsy.dmatrices(equation, data=train_df, return_type="dataframe")

# Create your model
model = smf.ols(equation, data = joined)

# Fit your model to your training set
fit = model.fit()

# Print summary statistics of the model's performance
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              num_weeks   R-squared:                       0.036
# Model:                            OLS   Adj. R-squared:                  0.027
# Method:                 Least Squares   F-statistic:                     4.025
# Date:                Wed, 18 Jul 2018   Prob (F-statistic):           6.98e-07
# Time:                        17:55:40   Log-Likelihood:                -5410.1
# No. Observations:                1526   AIC:                         1.085e+04
# Df Residuals:                    1511   BIC:                         1.093e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            5.3547      3.689      1.452      0.147      -1.882      12.591
# acousticness        -2.0584      1.092     -1.884      0.060      -4.201       0.084
# danceability         5.3604      1.764      3.039      0.002       1.900       8.821
# duration_ms          0.0014      0.003      0.460      0.646      -0.005       0.007
# energy              -1.2032      2.037     -0.591      0.555      -5.200       2.793
# instrumentalness    -2.6871      1.662     -1.617      0.106      -5.947       0.572
# key                  0.1604      0.062      2.607      0.009       0.040       0.281
# liveness            -2.0485      1.574     -1.301      0.193      -5.137       1.040
# loudness             0.0184      0.090      0.205      0.838      -0.158       0.195
# mode                 0.3213      0.513      0.626      0.531      -0.685       1.328
# popularity           0.0240      0.012      2.063      0.039       0.001       0.047
# speechiness        -10.7172      2.790     -3.841      0.000     -16.190      -5.244
# tempo                0.0075      0.008      0.915      0.360      -0.009       0.024
# time_signature       1.0242      0.733      1.396      0.163      -0.415       2.463
# valence             -1.0252      1.180     -0.869      0.385      -3.341       1.290
# ==============================================================================
# Omnibus:                      255.380   Durbin-Watson:                   0.073
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              606.919
# Skew:                           0.925   Prob(JB):                    1.62e-132
# Kurtosis:                       5.475   Cond. No.                     4.91e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.91e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# I will be using stats model formula

# %%
joined.columns
# Out:
# Index(['acousticness', 'danceability', 'duration_ms', 'energy', 'genre', 'id',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 'popularity',
#        'song', 'speechiness', 'tempo', 'time_signature', 'valence',
#        'num_weeks'],
#       dtype='object')

# %% [markdown]
# such trash

# %%
fit.resid.plot(style='o', figsize=(12,8));

# %% [markdown]
# This makes sense, because the 'top songs' were appened to the end of the dataframe so it would underfit for those lol

# %%
joined.columns
# Out:
# Index(['acousticness', 'danceability', 'duration_ms', 'energy', 'genre', 'id',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 'popularity',
#        'song', 'speechiness', 'tempo', 'time_signature', 'valence',
#        'num_weeks'],
#       dtype='object')

# %%
##break down the songs by the genre that they are categorized by

genre_count = {}
for index, row in enumerate(joined.genre):
    for genre in row:
        genre_count[genre] = genre_count.get(genre, 0) + 1

# %%
##here are the top 60 genres mentioned in the dataset

pd.Series(genre_count).sort_values(ascending=False)[:60]
# Out:
# pop                     280
# dance pop               279
# mellow gold             200
# pop rap                 198
# soft rock               195
# country                 162
# contemporary country    160
# rap                     156
# r&b                     154
# urban contemporary      151
# soul                    147
# folk rock               141
# motown                  140
# country road            138
# adult standards         137
# rock                    136
# hip hop                 131
# quiet storm             130
# christmas               127
# brill building pop      125
# funk                    123
# disco                   116
# post-teen pop           116
# southern hip hop        109
# classic rock            103
# classic soul            102
# album rock               99
# bubblegum pop            97
# trap music               84
# pop rock                 79
# new wave pop             79
# folk                     74
# modern country rock      71
# southern soul            64
# hip pop                  63
# lounge                   58
# art rock                 57
# rock-and-roll            55
# roots rock               54
# new jack swing           52
# hard rock                52
# rhythm and blues         50
# dirty south rap          50
# rockabilly               48
# traditional country      48
# country dawn             43
# gangster rap             43
# nashville sound          43
# post-disco               42
# edm                      39
# singer-songwriter        38
# neo soul                 38
# southern rock            38
# blues-rock               37
# country rock             36
# dance rock               35
# europop                  34
# neo mellow               34
# vocal jazz               30
# tropical house           30
# dtype: int64

# %%
##need to break down the genre into binary categories to be able to engineer this feature and use in linear reg

def has_genre(s_all, genre_synonms):
    for s in s_all:
        if s in genre_synonms:
            return True
    return False

def has_rock(s_all):
    for s in s_all:
        if 'rock' in s.lower():
            return True
    return False

def has_christmas(s_all):
    for s in s_all:
        if 'christmas' in s.lower():
            return True
    return False

# %% [markdown]
# ## Tease apart the genre and keys of the song

# %%
joined['is_rock'] = joined.genre.apply(has_rock)
#joined['is_christmas'] = joined.genre.apply(has_christmas)
#joined['is_pop'] = joined.genre.apply(has_pop)
#joined['is_disco'] = joined.genre.apply(lambda s: has_genre(s, ['disco']))
#joined['is_easylistening'] = joined.genre.apply(has_easylistening)
#joined['is_country'] = joined.genre.apply(has_country)

country_syn = ['country', 'folk', 'contemporary country', 'traditional country']
hiphop_syn = ['rap', 'hip hop', 'r&b', 'rhythm and blues', 'soul', 'funk', 'quiet storm', 'urban contemporary',
             'southern hip hop', 'southern soul', 'trap music']
easy_syn = ['easy listening', 'mellow gold', 'adult standards', 'neo melllow']
pop_syn = ['pop', 'disco', 'mowtown', 'metropolis', 'bubblegum dance', 'eurodance']
edm_syn = ['edm', 'dance pop', 'tropical house', 'vocal house']

joined['is_hiphop'] = joined.genre.apply(lambda s: has_genre(s, hiphop_syn))
joined['is_country'] = joined.genre.apply(lambda s: has_genre(s, country_syn))
joined['is_easy'] = joined.genre.apply(lambda s: has_genre(s, easy_syn))
joined['is_pop'] = joined.genre.apply(lambda s: has_genre(s, pop_syn))
joined['is_edm'] = joined.genre.apply(lambda s: has_genre(s, edm_syn))

joined.drop('genre', axis =1, inplace = True)
joined.columns
# Out:
# Index(['acousticness', 'danceability', 'duration_ms', 'energy', 'id',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 'popularity',
#        'song', 'speechiness', 'tempo', 'time_signature', 'valence',
#        'num_weeks', 'is_rock', 'is_hiphop', 'is_country', 'is_easy', 'is_pop',
#        'is_edm'],
#       dtype='object')

# %%
joined.corr().num_weeks
# Out:
# acousticness       -0.093309
# danceability        0.090253
# duration_ms         0.039701
# energy              0.034148
# instrumentalness   -0.051766
# key                 0.066319
# liveness           -0.054931
# loudness            0.041491
# mode               -0.007990
# popularity          0.082300
# speechiness        -0.051718
# tempo              -0.001131
# time_signature      0.061743
# valence            -0.005243
# num_weeks           1.000000
# is_rock             0.022956
# is_hiphop           0.000037
# is_country          0.048331
# is_easy            -0.035250
# is_pop              0.072520
# is_edm              0.117936
# Name: num_weeks, dtype: float64

# %%
equation = 'num_weeks ~ acousticness + danceability + duration_ms + energy + instrumentalness + key + liveness + loudness + mode + popularity + speechiness + tempo + time_signature + valence + is_rock + is_hiphop + is_country + is_easy + is_pop + is_edm'

y, X = patsy.dmatrices(equation, data=joined, return_type="dataframe")

# Create your model
model = sm.OLS(y, X)

# Fit your model to your training set
fit = model.fit()

# Print summary statistics of the model's performance
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              num_weeks   R-squared:                       0.046
# Model:                            OLS   Adj. R-squared:                  0.033
# Method:                 Least Squares   F-statistic:                     3.603
# Date:                Wed, 18 Jul 2018   Prob (F-statistic):           1.35e-07
# Time:                        17:56:21   Log-Likelihood:                -5402.4
# No. Observations:                1526   AIC:                         1.085e+04
# Df Residuals:                    1505   BIC:                         1.096e+04
# Df Model:                          20
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              4.9238      3.690      1.334      0.182      -2.315      12.163
# is_rock[T.True]        0.8099      0.595      1.361      0.174      -0.358       1.978
# is_hiphop[T.True]     -0.0924      0.553     -0.167      0.867      -1.176       0.991
# is_country[T.True]     1.1931      0.661      1.805      0.071      -0.103       2.490
# is_easy[T.True]       -0.6113      0.701     -0.873      0.383      -1.985       0.763
# is_pop[T.True]         0.3054      0.649      0.471      0.638      -0.967       1.578
# is_edm[T.True]         2.1065      0.697      3.022      0.003       0.739       3.474
# acousticness          -1.6493      1.100     -1.499      0.134      -3.807       0.509
# danceability           5.3570      1.835      2.920      0.004       1.759       8.956
# duration_ms            0.0019      0.003      0.619      0.536      -0.004       0.008
# energy                -0.9203      2.060     -0.447      0.655      -4.962       3.121
# instrumentalness      -2.4411      1.667     -1.464      0.143      -5.711       0.829
# key                    0.1614      0.061      2.627      0.009       0.041       0.282
# liveness              -1.9439      1.572     -1.237      0.216      -5.027       1.139
# loudness              -0.0350      0.092     -0.380      0.704      -0.216       0.146
# mode                   0.3125      0.519      0.602      0.547      -0.705       1.330
# popularity             0.0046      0.014      0.323      0.747      -0.023       0.032
# speechiness           -8.1896      2.965     -2.762      0.006     -14.005      -2.374
# tempo                  0.0071      0.008      0.866      0.387      -0.009       0.023
# time_signature         0.9280      0.733      1.267      0.205      -0.509       2.365
# valence               -1.0382      1.205     -0.861      0.389      -3.402       1.326
# ==============================================================================
# Omnibus:                      240.627   Durbin-Watson:                   0.093
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              550.165
# Skew:                           0.889   Prob(JB):                    3.41e-120
# Kurtosis:                       5.343   Cond. No.                     4.93e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.93e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
joined = pd.get_dummies(joined, columns = ['key'], drop_first = False)
joined.drop('key_11', axis =1, inplace = True)

# %%
joined.columns
# Out:
# Index(['acousticness', 'danceability', 'duration_ms', 'energy', 'id',
#        'instrumentalness', 'liveness', 'loudness', 'mode', 'popularity',
#        'song', 'speechiness', 'tempo', 'time_signature', 'valence',
#        'num_weeks', 'is_rock', 'is_hiphop', 'is_country', 'is_easy', 'is_pop',
#        'is_edm', 'key_0', 'key_1', 'key_2', 'key_3', 'key_4', 'key_5', 'key_6',
#        'key_7', 'key_8', 'key_9', 'key_10'],
#       dtype='object')

# %%
equation = 'num_weeks ~ acousticness  + danceability + duration_ms + energy + instrumentalness + liveness + loudness + mode + popularity + speechiness + tempo + time_signature + valence + is_rock + is_hiphop + is_country + is_easy + is_pop + is_edm + key_0 + key_1+ key_2 + key_3 + key_4 + key_5 + key_6 + key_7 + key_8 + key_9 + key_10'
#y, X = patsy.dmatrices(equation, data=train_df, return_type="dataframe")

# Create your model
model = smf.ols(equation, data = joined)

# Fit your model to your training set
fit = model.fit()

# Print summary statistics of the model's performance
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              num_weeks   R-squared:                       0.052
# Model:                            OLS   Adj. R-squared:                  0.032
# Method:                 Least Squares   F-statistic:                     2.706
# Date:                Wed, 18 Jul 2018   Prob (F-statistic):           2.12e-06
# Time:                        17:56:28   Log-Likelihood:                -5397.7
# No. Observations:                1526   AIC:                         1.086e+04
# Df Residuals:                    1495   BIC:                         1.102e+04
# Df Model:                          30
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              6.8535      3.751      1.827      0.068      -0.505      14.212
# is_rock[T.True]        0.9283      0.598      1.552      0.121      -0.245       2.102
# is_hiphop[T.True]     -0.0526      0.556     -0.095      0.925      -1.143       1.038
# is_country[T.True]     1.2061      0.665      1.814      0.070      -0.098       2.510
# is_easy[T.True]       -0.6465      0.703     -0.919      0.358      -2.026       0.733
# is_pop[T.True]         0.2862      0.653      0.439      0.661      -0.994       1.567
# is_edm[T.True]         2.0531      0.701      2.930      0.003       0.678       3.428
# acousticness          -1.7165      1.103     -1.556      0.120      -3.880       0.447
# danceability           5.3288      1.846      2.887      0.004       1.708       8.950
# duration_ms            0.0019      0.003      0.629      0.529      -0.004       0.008
# energy                -0.8417      2.068     -0.407      0.684      -4.899       3.215
# instrumentalness      -2.3670      1.674     -1.414      0.157      -5.650       0.916
# liveness              -1.7901      1.580     -1.133      0.257      -4.890       1.310
# loudness              -0.0355      0.093     -0.383      0.701      -0.217       0.146
# mode                   0.2799      0.529      0.529      0.597      -0.757       1.317
# popularity             0.0036      0.014      0.250      0.803      -0.024       0.032
# speechiness           -8.9087      2.996     -2.973      0.003     -14.786      -3.032
# tempo                  0.0064      0.008      0.772      0.440      -0.010       0.023
# time_signature         0.8980      0.734      1.224      0.221      -0.541       2.337
# valence               -1.1487      1.210     -0.949      0.343      -3.522       1.225
# key_0                 -2.0792      1.013     -2.052      0.040      -4.067      -0.091
# key_1                  0.0697      1.072      0.065      0.948      -2.033       2.173
# key_2                 -1.9313      1.055     -1.830      0.067      -4.001       0.138
# key_3                 -1.6456      1.471     -1.119      0.264      -4.531       1.240
# key_4                 -0.9369      1.158     -0.809      0.419      -3.208       1.334
# key_5                 -0.5205      1.060     -0.491      0.623      -2.600       1.559
# key_6                 -1.9524      1.152     -1.694      0.090      -4.213       0.308
# key_7                 -0.1478      1.038     -0.142      0.887      -2.184       1.888
# key_8                 -0.1320      1.127     -0.117      0.907      -2.343       2.079
# key_9                  0.0378      1.073      0.035      0.972      -2.066       2.142
# key_10                 0.0517      1.172      0.044      0.965      -2.246       2.350
# ==============================================================================
# Omnibus:                      228.858   Durbin-Watson:                   0.105
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              503.357
# Skew:                           0.864   Prob(JB):                    4.98e-110
# Kurtosis:                       5.221   Cond. No.                     5.06e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.06e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### Scaled x_train

# %%
X = joined.drop(['num_weeks', 'id', 'song'], 1)
y = joined.num_weeks
#print(X.columns)


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
#print((y_train))
ss_x = StandardScaler()
X_train_scaled = pd.DataFrame(ss_x.fit_transform(X_train), columns=X_train.columns, index=X_train.index)
#print((X_train_scaled))
X_test_scaled = ss_x.transform(X_test)

"""X_train_scaled.rename(columns = {0:'acousticness', 1:'danceability', 2:'duration_ms', 3:'energy',
       4:'instrumentalness', 5:'liveness', 6:'loudness', 7:'mode', 8:'popularity',
       9:'speechiness', 10:'tempo', 11:'time_signature', 12:'valence', 13:'is_rock',
       14:'is_hiphop', 15:'is_country', 16:'is_easy', 17:'is_pop', 18:'is_edm', 19:'key_0',
       20:'key_1', 21:'key_2', 22:'key_3',23: 'key_4', 24:'key_5', 25:'key_6', 26:'key_7', 27:'key_8',
       28:'key_9', 29:'key_10'}, inplace = True)
"""
#print(X_train_scaled)
train_scaled_with_weeks = X_train_scaled.copy(deep = True)
print(y_train)
train_scaled_with_weeks['num_weeks'] = y_train
#print(X_train_scaled_with_weeks.head(20))
train_scaled_with_weeks
#train_df_scaled = X_train_scaled
# Out:
# 16413     5.0
# 14680    23.0
# 13998    20.0
# 2140     14.0
# 10203     2.0
# 12413    16.0
# 1773     14.0
# 7546     20.0
# 17179    20.0
# 3708   3.181981 -0.266859       15.0
# 2896  -0.314270 -0.266859       20.0
# 6678  -0.314270 -0.266859       13.0
# 16899 -0.314270 -0.266859       20.0
# 16455 -0.314270 -0.266859        5.0
# 6196  -0.314270 -0.266859       28.0
# 16976 -0.314270 -0.266859       16.0
# 13350 -0.314270 -0.266859        6.0
# 13181 -0.314270 -0.266859       14.0
# 12597 -0.314270 -0.266859        9.0
# 9103  -0.314270 -0.266859       20.0
# ...         ...       ...        ...
# 1236  -0.314270 -0.266859       12.0
# 14025 -0.314270 -0.266859       14.0
# 11273 -0.314270 -0.266859       15.0
# 14596 -0.314270 -0.266859       17.0
# 2637   3.181981 -0.266859       20.0
# 12387 -0.314270 -0.266859        9.0
# 13539 -0.314270 -0.266859        9.0
# 11080 -0.314270 -0.266859       15.0
# 13434  3.181981 -0.266859       20.0
# 5005  -0.314270 -0.266859       26.0
# 14516 -0.314270 -0.266859       20.0
# 10802 -0.314270 -0.266859        7.0
# 13315 -0.314270 -0.266859        3.0
# 15272 -0.314270 -0.266859       12.0
# 13596 -0.314270 -0.266859        1.0
# 8271   3.181981 -0.266859       15.0
# 2998  -0.314270 -0.266859       13.0
# 9501  -0.314270 -0.266859        9.0
# 14100 -0.314270 -0.266859       20.0
# 1005   3.181981 -0.266859       17.0
# 4452  -0.314270 -0.266859       17.0
# 14499 -0.314270 -0.266859       20.0
# 14000 -0.314270 -0.266859       19.0
# 16066 -0.314270 -0.266859       12.0
# 519    3.181981 -0.266859       14.0
# 7981  -0.314270 -0.266859        2.0
# 11624 -0.314270 -0.266859       15.0
# 15113 -0.314270 -0.266859        9.0
# 12519 -0.314270  3.747299       26.0
# 7890  -0.314270 -0.266859       25.0
#
# [1068 rows x 31 columns]

# %% [markdown]
# # NOW this is my baseline model finally

# %%
#train_scaled_with_weeks['num_weeks2'] = train_scaled_with_weeks['num_weeks']**2

equation = 'num_weeks2 ~ acousticness  + danceability + duration_ms + energy + instrumentalness + liveness + loudness + mode + popularity + speechiness + tempo + time_signature + valence + is_rock + is_hiphop + is_country + is_easy + is_pop + is_edm + key_0 + key_1+ key_2 + key_3 + key_4 + key_5 + key_6 + key_7 + key_8 + key_9 + key_10'
#y, X = patsy.dmatrices(equation, data=train_df, return_type="dataframe")

# Create your model
model = smf.ols(equation, data = train_scaled_with_weeks)

# Fit your model to your training set
fit = model.fit()

# Print summary statistics of the model's performance
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             num_weeks2   R-squared:                       0.069
# Model:                            OLS   Adj. R-squared:                  0.042
# Method:                 Least Squares   F-statistic:                     2.552
# Date:                Wed, 18 Jul 2018   Prob (F-statistic):           1.06e-05
# Time:                        18:41:54   Log-Likelihood:                -7643.1
# No. Observations:                1068   AIC:                         1.535e+04
# Df Residuals:                    1037   BIC:                         1.550e+04
# Df Model:                          30
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept          236.0861      9.635     24.502      0.000     217.179     254.993
# acousticness       -19.4980     13.713     -1.422      0.155     -46.406       7.410
# danceability        24.3082     13.055      1.862      0.063      -1.308      49.925
# duration_ms          5.6709     10.478      0.541      0.588     -14.890      26.232
# energy             -23.7299     18.821     -1.261      0.208     -60.661      13.201
# instrumentalness    -9.1974     10.206     -0.901      0.368     -29.224      10.830
# liveness           -10.7668     10.243     -1.051      0.293     -30.866       9.333
# loudness            20.1356     16.366      1.230      0.219     -11.978      52.249
# mode                -3.8440     10.418     -0.369      0.712     -24.286      16.598
# popularity          16.2083     13.277      1.221      0.222      -9.844      42.261
# speechiness        -29.7353     11.456     -2.596      0.010     -52.215      -7.255
# tempo                2.7502     10.220      0.269      0.788     -17.304      22.804
# time_signature      13.9471     10.392      1.342      0.180      -6.445      34.339
# valence            -16.5687     12.892     -1.285      0.199     -41.866       8.729
# is_rock              8.1137     12.694      0.639      0.523     -16.796      33.023
# is_hiphop          -23.0584     11.628     -1.983      0.048     -45.875      -0.242
# is_country           9.9277     11.320      0.877      0.381     -12.286      32.141
# is_easy            -12.8082     12.097     -1.059      0.290     -36.546      10.929
# is_pop              12.7918     13.160      0.972      0.331     -13.032      38.616
# is_edm              23.8114     12.526      1.901      0.058      -0.769      48.392
# key_0              -19.8990     14.980     -1.328      0.184     -49.293       9.495
# key_1                6.0512     13.582      0.446      0.656     -20.600      32.702
# key_2              -17.1717     14.357     -1.196      0.232     -45.343      11.000
# key_3              -11.5547     11.345     -1.018      0.309     -33.817      10.708
# key_4              -22.7656     12.644     -1.801      0.072     -47.576       2.045
# key_5               -3.7172     13.909     -0.267      0.789     -31.011      23.577
# key_6               -9.7648     13.152     -0.742      0.458     -35.573      16.043
# key_7               -6.6412     14.326     -0.464      0.643     -34.753      21.471
# key_8                8.3714     13.522      0.619      0.536     -18.162      34.905
# key_9               -7.5239     13.753     -0.547      0.584     -34.511      19.463
# key_10               8.8172     12.891      0.684      0.494     -16.479      34.113
# ==============================================================================
# Omnibus:                      993.442   Durbin-Watson:                   1.947
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            45315.870
# Skew:                           4.204   Prob(JB):                         0.00
# Kurtosis:                      33.784   Cond. No.                         6.64
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
train_scaled_with_weeks.columns
# Out:
# Index(['acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'liveness', 'loudness', 'mode', 'popularity',
#        'speechiness', 'tempo', 'time_signature', 'valence', 'is_rock',
#        'is_hiphop', 'is_country', 'is_easy', 'is_pop', 'is_edm', 'key_0',
#        'key_1', 'key_2', 'key_3', 'key_4', 'key_5', 'key_6', 'key_7', 'key_8',
#        'key_9', 'key_10', 'num_weeks'],
#       dtype='object')

# %%
# 5-fold cross-validation with our fake data
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import PolynomialFeatures

model = LinearRegression()
scores = cross_val_score(model, X_train_scaled, y_train, cv=5, scoring='neg_mean_squared_error')

# scores output is negative, a sklearn quirk bc mse is used to min. optimization func.
print(np.sqrt(-scores))
# Out:
# [ 9.90344665  8.31028757  7.93580345  8.37648063  7.7354836 ]

# %%
from sklearn.metrics import mean_squared_error

quad = PolynomialFeatures(degree=3)
X_train_scaled_quad = quad.fit_transform(X_train_scaled)

model.fit(X_train_scaled_quad, y_train)
y_predict = model.predict(X_train_scaled_quad)
np.sqrt(mean_squared_error(y_predict, y_train))
# Out:
# 1.1894373644507805e-13

# %%
from sklearn.linear_model import LassoCV, RidgeCV

alphas = [10**x for x in range(-6,6)]
ridge = LassoCV(alphas=alphas, cv = 5, max_iter=4000)

ridge.fit(X_train_scaled_quad, y_train)

# %%
y_predict = ridge.predict(X_train_scaled_quad)
np.sqrt(mean_squared_error(y_predict, y_train))
# Out:
# 7.9204735550757768

# %%
ridge.alpha_
# Out:
# 100000

# %%
#sns.pairplot(train_df_scaled)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

rf = RandomForestRegressor()

param_grid = {
    'n_estimators': [50, 100, 150, 200],
    'max_depth': [4, 5, 6],
    'min_samples_leaf': [20, 25, 30, 50, 70]
}
grid = GridSearchCV(rf, param_grid=param_grid, scoring='neg_mean_squared_error')
grid.fit(X_train_scaled, y_train)
print(grid.score(X_train_scaled,y_train))
y_predict = grid.predict(X_train_scaled)
np.sqrt(mean_squared_error(y_predict, y_train))

# %%
plt.scatter(y_predict, y_predict - y_train)

# %% [markdown]
# ## Let's look at the residuals for this model fit

# %%
fit.resid.plot(style='o', figsize=(12,8));

# %% [markdown]
# # I think I need to cross validate this base model?

# %%
from sklearn.cross_validation import cross_val_score

# %%
train_df_scaled.info()

# %%
X_train_scaled.head(20)

# %%
# 10-fold cross-validation with our fake data
reg = LinearRegression()
scores = cross_val_score(reg, X_train_scaled, y_train, cv=5, scoring='mean_squared_error')

# scores output is negative, a sklearn quirk bc mse is used to min. optimization func.
print(-scores)

# %% [markdown]
# # This is me attempting to do some regularization

# %%
X_train_scaled
y_train

# %%
kf = KFold(n=len(X), n_folds=5, shuffle=False)
alphas = [10**x for x in range(-12, 5)]
scores = np.zeros((len(alphas),1))

# %%
for j in range(len(alphas)):
    kf_score = []
    for train, test in kf:
        X_train = X_train_scaled.iloc[train]
        y_train = y_train.iloc[train]
        X_test = X_train_scaled.iloc[test]
        y_test = y_tra.iloc[test]
        std_scaler = preprocessing.StandardScaler()
        X_train_norm = std_scaler.fit_transform(X_train)
        X_test_norm = std_scaler.transform(X_test)
    
        model =  Lasso(alpha = alphas[j])
        model.fit(X_train_norm, y_train)
        y_test_predict = model.predict(X_test_norm)
        score = mean_squared_error(y_test_predict, y_test)
        kf_score.append(score)
    scores[j] = np.mean(kf_score)
print ('mse for all alpha values \n')
print (pd.DataFrame(list(zip(alphas, scores)), columns=['alpha', 'mse']))

best_alpha = alphas[scores.argmin()]
print ('best alpha is:', best_alpha)

# %%
#diagnostic plots dont work :(
diagnostic_plots.diagnostic_plots(train_df.drop('num_weeks', axis=1), train_df['num_weeks'], fit)

# %% [markdown]
# ## doing it with sklearn

# %%
linear_model = LinearRegression()
linear_model.fit(train_df.drop('num_weeks', 1), train_df['num_weeks'])
linear_model.score(train_df.drop('num_weeks', 1), train_df['num_weeks'])

# %%
# Pick a coefficient d and make the features!
x_values = train_df.drop('num_weeks', 1)

def get_polynomial_features(degree, x_values):
    return PolynomialFeatures(degree=degree).fit_transform(x_values)

def get_polynomial_fit(degree, x_values, y_values):
    X = get_polynomial_features(degree, x_values)
    # we already have a column of "1"s for the intercept, 
    # so don't ask LinearRegression to make one as well
    model = LinearRegression(fit_intercept=False)
    model.fit(X, y_values)
    print("Score of the model is {}".format(model.score(X, y_values)))
    
    return model

def plot_polynomial_model(degree, x_values, y_values):
    model = get_polynomial_fit(degree, x_values, y_values)
    # plot points
    plt.plot(x_values, y_values, 'ro')
    
    # make the curve
    x_curve = np.arange(0,17,0.1).reshape(-1,1)
    X_curve = get_polynomial_features(degree, x_curve)
    y_curve = model.predict(X_curve)
    plt.plot(x_curve, y_curve)
    plt.ylim((0,160))
    


# example
get_polynomial_features(2, x_values)

# %%
def plot_predict_and_points(x_values, y_values, model):
    y_predict = model.predict(x_values)

    plt.plot(x_values[:,0], y_values, 'ro')
    plt.plot(x_values[:,0], y_predict, 'b--')
    plt.xlabel('x')
    plt.ylabel('y')

# %%
plot_predict_and_points(train_df.drop('num_weeks', 1), train_df['num_weeks'], linear_model)

# %% [markdown]
# ## c r o s s v a l i d a t i o n

# %%
from sklearn.cross_validation import cross_val_score

# %%
# 10-fold cross-validation with our fake data
reg = LinearRegression()
scores = cross_val_score(reg, X_train, y_train, cv=10, scoring='mean_squared_error')

# scores output is negative, a sklearn quirk bc mse is used to min. optimization func.
print(-scores)
#root mean squared errors telling us the root(mean((actual - predicted)**2)) therefore want to minimize!

# %%
est=LinearRegression()

kf=KFold(n=len(X),n_folds=5,shuffle=True)

all_scores=[]

# Instead of using cross_val_score, let's use sklearn.cross_validation.KFold; this will allow
# us to 'manipulate' our training set, 

# get indices of corresponding train & test
for train,test in kf:
    x_train=X.iloc[train]
    y_train=y.iloc[train]
    x_test=X.iloc[test]
    y_test=y.iloc[test]
    pvals=[]
    sig_cols=[]
    
    for feature in x_train.columns:
        pval=f_select.f_regression(x_train[[feature]],y_train)
        if pval[1][0]<.02: 
            sig_cols.append(feature)
            pvals.append(pval[1][0])
            
    est.fit(x_train[sig_cols],y_train)
    r_2=est.score(x_test[sig_cols],y_test)
    all_scores.append(r_2)
        
#np.mean(all_scores)

# %%
np.log(train_df.popularity + 1).hist()

# %%
sns.pairplot(train_df, vars = ['num_weeks', 'popularity', 'danceability', 'is_pop', 'is_edm', 'is_hiphop'])

# %% [markdown]
# ## Base Linear Regression Model

# %%
useful_dataset_with_keys = pd.read_pickle('Modeling/dataset_used_for_modeling.pkl')

# %%
#results.resid.plot(style='o', figsize=(12,8));
diagnostic_plots.diagnostic_plots(useful_dataset_with_keys.drop('num_weeks', axis=1), 
                                  useful_dataset_with_keys['num_weeks'], results)

# %%
# Diagnostic Plots
import scipy.stats as stats
def diagnostic_plot(x, y):
    plt.figure(figsize=(20,5))
    
    rgr = LinearRegression()
    rgr.fit(x.reshape(-1,1),y)
    pred = rgr.predict(x.reshape(-1,1))

    plt.subplot(1, 3, 1)
    plt.scatter(x,y)
    plt.plot(x, pred, color='blue',linewidth=1)
    plt.title("Regression fit")
    plt.xlabel("x")
    plt.ylabel("y")
    
    plt.subplot(1, 3, 2)
    res = y - pred
    plt.scatter(pred, res)
    plt.title("Residual plot")
    plt.xlabel("prediction")
    plt.ylabel("residuals")
    
    plt.subplot(1, 3, 3)
    #Generates a probability plot of sample data against the quantiles of a 
    # specified theoretical distribution 
    stats.probplot(res, dist="norm", plot=plt)
    plt.title("Normal Q-Q plot")
    
# # Generate some data
# s = 30
# x = np.random.uniform(low=-5, high=5, size=s)

# ep = 2*np.random.randn(s)
# beta = 2
# y = beta*x + ep

# diagnostic_plot(x,y)

# %%
useful_dataset_with_keys['log_num_weeks'] = np.log(useful_dataset_with_keys.num_weeks + 1).hist()
useful_dataset_with_keys.drop('num_weeks',1, inplace = True)

diagnostic_plot(X_train, y_train)

# %%
type(useful_dataset_with_keys.log_num_weeks)

# %%
useful_dataset_with_keys.columns

# %%
diagnostic_plots.diagnostic_plots(useful_dataset_with_keys.drop('log_num_weeks', axis=1), 
                                  useful_dataset_with_keys['log_num_weeks'], results)

# %%
def plot_predict_and_points(x_values, y_values, model):
    y_predict = model.predict(x_values)

    plt.plot(x_values[:,0], y_values, 'ro')
    plt.plot(x_values[:,0], y_predict, 'b--')
    plt.xlabel('x')
    plt.ylabel('y')
    
#plot_predict_and_points(x_values, y_values, linear_model)
#plt.title('This IS the line that best fits the data');

# %%
# Create your feature matrix (X) and target vector (y)

equation = 'num_weeks ~ duration_ms + key + loudness + tempo + time_signature  + '
y, X = patsy.dmatrices(equation, data=joined)

model = sm.OLS(y, X)
model_fit = model.fit()
model_fit.summary()

# %%
#might have to drop some columns based on how the

# %%
linear_model = LinearRegression()
linear_model.fit(df.key.reshape(-1,1), useful_dataset_with_keys.num_weeks)
linear_model.score(df.key.reshape(-1,1), useful_dataset_with_keys.num_weeks)

plot_predict_and_points(df.key.reshape(-1,1), df.num_weeks, linear_model)
plt.title('This is NOT the line that best fits the data--High Bias');
plt.xlabel('Song Key');
plt.ylabel('Number of Weeks on Billboard');

#plt.savefig('first_model.png', dpi=1000)

# %%
import matplotlib.pyplot as plt

#pd.Series(fit.resid).plot(style='o', figsize=(12,8));

y_predict = model_fit.predict(X)
y_resid = y.reshape(-1,) - y_predict

#y_resid.shape
plt.plot(y.reshape(-1,), y_resid.reshape(-1,),'o');
plt.xlabel('y_true')
plt.ylabel('residual')

#plt.savefig('first_model_residual.png', dpi=1000)

# %%
linear_model = LinearRegression()
linear_model.fit(df.key.reshape(-1,1), df.num_weeks.reshape(-1,1))
linear_model.score(df.key.reshape(-1,1), df.num_weeks.reshape(-1,1))

# %% [markdown]
# ## Robert's Diagnostic Plots

# %%
# model values
model_fitted_y = model_fit.fittedvalues
#print(df.columns[-1])
#print(len(model_fitted_y))
# model residuals
model_residuals = model_fit.resid
# normalized residuals
model_norm_residuals = model_fit.get_influence().resid_studentized_internal
# absolute squared normalized residuals
model_norm_residuals_abs_sqrt = np.sqrt(np.abs(model_norm_residuals))
# absolute residuals
model_abs_resid = np.abs(model_residuals)
# leverage, from statsmodels internals
model_leverage = model_fit.get_influence().hat_matrix_diag
# cook's distance, from statsmodels internals
model_cooks = model_fit.get_influence().cooks_distance[0]

plot_lm_1 = plt.figure()
plot_lm_1.axes[0] = sns.residplot(model_fitted_y, np.asarray(df.columns[-1]), data=df,
                          lowess=True,
                          scatter_kws={'alpha': 0.5},
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})

plot_lm_1.axes[0].set_title('Residuals vs Fitted')
plot_lm_1.axes[0].set_xlabel('Fitted values')
plot_lm_1.axes[0].set_ylabel('Residuals');

# %%
(df.num_weeks)
