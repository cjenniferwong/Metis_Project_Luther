# %%
import pandas as pd

top_200 = pd.read_csv('regional-global-daily-latest.csv')
top_200.rename()
# Out:
#     Unnamed: 0                             Unnamed: 1           Unnamed: 2  \
# 0     Position                             Track Name               Artist
# 1            1                         In My Feelings                Drake
# 2            2                     Don’t Matter To Me                Drake
# 3            3                                   SAD!         XXXTENTACION
# 4            4                                Nonstop                Drake
# 5            5         Girls Like You (feat. Cardi B)             Maroon 5
# 6            6                           Lucid Dreams           Juice WRLD
# 7            7                              I Like It              Cardi B
# 8            8               One Kiss (with Dua Lipa)        Calvin Harris
# 9            9                             Better Now          Post Malone
# 10          10               Solo (feat. Demi Lovato)         Clean Bandit
# ...
