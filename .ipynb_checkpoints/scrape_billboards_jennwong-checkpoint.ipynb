# %% [markdown]
# ## Scrapping Billboards Weekly Top 100 Songs
# Used to be merged with Kaggle Million Song Dataset for Linear Regression Analysis

# %%
import h5py
import numpy as np
import datetime as dt
import pandas as pd
from time import sleep


#did you check if there are other subcategories of top 100 chartss?
#maybe also get streaming data of all these songs? but also need to get rate bc different amount depending on how long the song has been released
#much of the data is coming from spotify therefore need to be aware of the consumer demographic and the bias present
#how does billboards determine who cracks the top 100?

# %% [markdown]
# ## Jenn scrapes her first website <3

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd


def get_billboard(url_list):
    """
    this function takes a list of urls and returns a data frame of that top 100 songs (names and artists)
    """
    complete_df = pd.DataFrame()
    df_list = [] #this is a going to be a list of data frames to be concat
    for url in url_list:
        source_code = requests.get(url)
        soup = BeautifulSoup(source_code.text, 'html5lib')
        top_100 = soup.find_all('div', class_='chart-row__title')
        names = []
        artists = []
        for song in top_100:
            names.append(song.find('h2').text)
            try:
                artist = song.find('a').text
                artists.append(artist.replace('\n', ''))
            except:
                artist = song.find('span').text
                artists.append(artist.replace('\n', ''))
        #print(artist, names)
        df_top_100 = pd.DataFrame()
        df_top_100['Song'] = names
        df_top_100['Artist'] = artists
        add = url.split('/')[-1]
        df_top_100.to_pickle(f'Jomas_Pickle/{add}.pkl')
        df_list.append(df_top_100)
        #break
        #sleep(1);
    complete_df = pd.concat(df_list)
    #print('done')
    #print(complete_df)
    return complete_df

# %%
end_date = dt.datetime(1998,5,9)
start_date = dt.datetime.now()

def get_url(start_date, end_date):
    url_list = []
    #end_date = dt.datetime.now()
    while start_date < end_date:
        url = f'https://www.billboard.com/charts/hot-100/{start_date.year}-{start_date.month:02}-{start_date.day:02}'
        url_list.append(url)
        start_date += dt.timedelta(days=7)
    return url_list
#str.split()

# %%
#%%timeit #tells me that it takes 1.72 seconds to run through 5 urls
#5.22 s for 10 urls
#start_date = dt.datetime(1998,5,4)
#end_date = dt.datetime.now()
url_list = get_url(start_date, end_date)
songs_df = get_billboard(url_list)
#songs_df
#url_list[::-1]

# %% [markdown]
# ## After scraping through all the web pages I want to store everything into a pickle file or csv so I don't have to do it again

# %%
unpickled_df = pd.read_pickle('Jomas_Pickle/1958-08-11.pkl')
unpickled_df
# Out:
#                                                  Song  \
# 0                                    Poor Little Fool
# 1                     Nel Blu Dipinto Di Blu (Volaré)
# 2                                            Patricia
# 3                                       Splish Splash
# 4                                                When
# 5                                        My True Love
# 6                                   Hard Headed Woman
# 7                                       Rebel-'rouser
# 8                                        Just A Dream
# 9                            Willie And The Hand Jive
# 10                                         Yakety Yak
# 11                                If Dreams Came True
# 12                                              Fever
# 13                                        Little Star
# 14                                       Ginger Bread
# 15                            Everybody Loves A Lover
# 16                                   One Summer Night
# 17                                      Born Too Late
# 18  Left Right Out Of Your Heart (Hi Lee Hi Lo Hi ...
# 19                                      Endless Sleep
# 20                                     Western Movies
# 21                       Guess Things Happen That Way
# 22                             For Your Precious Love
# 23                               Early In The Morning
# 24                                Somebody Touched Me
# 25                                Are You Really Mine
# 26                               Do You Want To Dance
# 27                                    A Certain Smile
# 28                                   Enchanted Island
# 29                                          Moon Talk
# ..                                                ...
# 70                                           Midnight
# 71                                        Little Mary
# 72                                 Tears On My Pillow
# 73                                            Kathy-O
# 74                     Let's Go Steady For The Summer
# 75                                       Just Married
# 76                                         Jennie Lee
# 77                         Harvey's Got A Girl Friend
# 78      She Was Only Seventeen (He Was One Year More)
# 79                                        Happy Years
# 80                       Young And Warm And Wonderful
# 81                                       Looking Back
# 82                                           Jealousy
# 83                                You're A Sweetheart
# 84                                         The Wizard
# 85                                      Moonlight Bay
# 86                                   Come In Stranger
# 87                                            Cerveza
# 88     The Purple People Eater Meets The Witch Doctor
# 89                                      Don't Go Home
# 90                          All I Have To Do Is Dream
# 91                                          La Paloma
# 92                                   I Believe In You
# 93                                         Midnighter
# 94                                       Chariot Rock
# 95                                   Down In Virginia
# 96                                    Sunday Barbecue
# 97                                    Gotta Have Rain
# 98                               Nothing In The World
# 99                         Baubles, Bangles And Beads
#
#                                          Artist
# 0                                  Ricky Nelson
# 1                              Domenico Modugno
# 2                 Perez Prado And His Orchestra
# 3                                   Bobby Darin
# 4                                   Kalin Twins
# 5                                    Jack Scott
# 6            Elvis Presley With The Jordanaires
# 7   Duane Eddy His Twangy Guitar And The Rebels
# 8                 Jimmy Clanton And His Rockets
# 9                          The Johnny Otis Show
# 10                                 The Coasters
# 11                                    Pat Boone
# 12                                    Peggy Lee
# 13                                 The Elegants
# 14                               Frankie Avalon
# 15                                    Doris Day
# 16                                 The Danleers
# 17                                   Poni-Tails
# 18                                   Patti Page
# 19                                Jody Reynolds
# 20                                 The Olympics
# 21            Johnny Cash And The Tennessee Two
# 22             Jerry Butler and The Impressions
# 23                              The Rinky-Dinks
# 24           Buddy Knox with the Rhythm Orchids
# 25                               Jimmie Rodgers
# 26                                Bobby Freeman
# 27                                Johnny Mathis
# 28                                The Four Lads
# 29                                   Perry Como
# ..                                          ...
# 70                                    Paul Anka
# 71                                  Fats Domino
# 72             Little Anthony And The Imperials
# 73                                 The Diamonds
# 74                                The Three G's
# 75                                Marty Robbins
# 76                                  Jan & Arnie
# 77                                  Royal Teens
# 78                                Marty Robbins
# 79                                 The Diamonds
# 80                                 Tony Bennett
# 81                                Nat King Cole
# 82                                  Kitty Wells
# 83                           Little Willie John
# 84                               Jimmie Rodgers
# 85                                 The Drifters
# 86            Johnny Cash And The Tennessee Two
# 87             Boots Brown And His Blockbusters
# 88                                    Joe South
# 89                                The Playmates
# 90                          The Everly Brothers
# 91               Billy Vaughn And His Orchestra
# 92                              Robert & Johnny
# 93                                   The Champs
# 94                                   The Champs
# 95                                   Jimmy Reed
# 96                         Tennessee Ernie Ford
# 97                                  Eydie Gorme
# 98                                Nat King Cole
# 99                         The Kirby Stone Four
#
# [100 rows x 2 columns]

# %% [markdown]
# ## I want to load the pkl file into the notebook and manipulate it: count how many times the artist and song shows up in the dataframe --> that will indicate how many week the song appears in the Billboards Top 100 Chart
